# %% [markdown]
# <a href="https://colab.research.google.com/github/sara-zeus/matplotlib-Problems-/blob/main/Combined_Debt_Growth_Over_Time.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
np.random.seed(444)

# %%
rng=np.arange(50)

# %%
rnd=np.random.randint(0,10,size=(3,rng.size))
rnd
# Out:
# array([[0, 3, 5, 2, 2, 6, 3, 3, 0, 7, 1, 0, 2, 4, 2, 1, 5, 8, 3, 5, 7, 7,
#         5, 0, 4, 1, 4, 4, 7, 6, 6, 3, 8, 7, 7, 6, 0, 3, 4, 4, 0, 9, 9, 6,
#         8, 8, 7, 1, 2, 0],
#        [5, 5, 9, 2, 8, 3, 1, 9, 8, 6, 6, 8, 7, 4, 3, 1, 2, 2, 8, 5, 8, 5,
#         4, 6, 0, 6, 0, 0, 9, 9, 3, 9, 9, 1, 7, 0, 9, 4, 9, 4, 3, 9, 6, 7,
#         7, 2, 5, 9, 0, 9],
#        [8, 4, 8, 2, 7, 3, 2, 1, 0, 7, 7, 7, 7, 1, 5, 5, 2, 7, 2, 3, 4, 7,
#         6, 8, 4, 6, 8, 5, 7, 7, 1, 8, 9, 4, 2, 5, 5, 5, 0, 7, 0, 4, 0, 3,
#         5, 5, 3, 2, 9, 6]])

# %%
yrs= 1950+rng

# %%
print(rng+rnd)
# Out:
# [[ 0  4  7  5  6 11  9 10  8 16 11 11 14 17 16 16 21 25 21 24 27 28 27 23
#   28 26 30 31 35 35 36 34 40 40 41 41 36 40 42 43 40 50 51 49 52 53 53 48
#   50 49]
#  [ 5  6 11  5 12  8  7 16 16 15 16 19 19 17 17 16 18 19 26 24 28 26 26 29
#   24 31 26 27 37 38 33 40 41 34 41 35 45 41 47 43 43 50 48 50 51 47 51 56
#   48 58]
#  [ 8  5 10  5 11  8  8  8  8 16 17 18 19 14 19 20 18 24 20 22 24 28 28 31
#   28 31 34 32 35 36 31 39 41 37 36 40 41 42 38 46 40 45 42 46 49 50 49 49
#   57 55]]

# %%
import matplotlib.pyplot as plt
import numpy as np


fig, ax = plt.subplots(figsize=(5, 3))
ax.stackplot(yrs, rng + rnd, labels=['Eastasia', 'Eurasia', 'Oceania'])
ax.set_title('Combined Debt Growth Over Time')
ax.legend(loc='upper left')
ax.set_ylabel('Total Debt')
ax.set_xlim(left=yrs[0], right=yrs[-1])

fig.tight_layout()
plt.show()
